# %%
import numpy as np

# %%
a = np.array([-1, 2, 3, 4, 5, -1])

# %%
a[np.array([True, False, True, True, False])]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 a[np.array([True, False, True, True, False])]
#
# IndexError: boolean index did not match indexed array along axis 0; size of axis is 6 but size of corresponding boolean axis is 5

# %%
a[np.array([0, 0, 1, 2, 3, 2, 0, 2])]
# Out:
# array([-1, -1,  2,  3,  4,  3, -1,  3])

# %%
a[a < 0]
# Out:
# array([-1, -1])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(np.array([1,2, 3, 4]), np.array([4, 5, 6, 7]))

plt.axis([0.5, 5, 0, 8])
# plt.fill_between(2, 3, alpha=0.4)
plt.xlabel(r"$\frac{\partial J}{\partial w}$")
plt.ylabel("$\\frac{1}{2}$")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 4
#       1 plt.scatter(np.array([1,2, 3, 4]), np.array([4, 5, 6, 7]))
#       3 plt.axis([0.5, 5, 0, 8])
# ----> 4 plt.fill_between(2, 3, alpha=0.4)
#       5 plt.xlabel(r"$\frac{\partial J}{\partial w}$")
#       6 plt.ylabel("$\\frac{1}{2}$")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3342, in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    3330 @_copy_docstring_and_deprecators(Axes.fill_between)
#    3331 def fill_between(
#    3332     x: ArrayLike,
#    (...)
#    3340     **kwargs,
#    3341 ) -> FillBetweenPolyCollection:
# -> 3342     return gca().fill_between(
#    3343         x,
#    3344         y1,
#    3345         y2=y2,
#    3346         where=where,
#    3347         interpolate=interpolate,
#    3348         step=step,
# ...

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = np.array([0, -1, -2])

# a = np.c_[a, b, c]

# %%
a
# Out:
# array([1, 2, 3])

# %%
a = np.column_stack([a, b, c])

# %%
a
# Out:
# array([[ 1,  4,  0],
#        [ 2,  5, -1],
#        [ 3,  6, -2]])

# %%
a = np.array([True, False, True, False])
a = a.astype(int)
a
# Out:
# array([1, 0, 1, 0])

# %%
np.log(1)
# Out:
# np.float64(0.0)

# %%
np.log10(10)
# Out:
# np.float64(1.0)

# %%
np.log2(2)
# Out:
# np.float64(1.0)
