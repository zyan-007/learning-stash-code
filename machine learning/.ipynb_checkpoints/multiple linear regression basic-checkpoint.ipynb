# %%
import numpy as np
import math
import copy

# %%
x_train = np.array([[2.10, 5, 1, 45], [1.42, 3, 2, 40], [1.53, 3, 2, 30], [0.85, 2, 1, 36], [1.94, 4, 2, 15], [1.10, 3, 1, 50], [2.35, 4, 2, 8], [1.68, 3, 1, 25]])
y_train = np.array([460, 232, 315, 178, 412, 205, 495, 340])

# %%
w = np.array([180.0, 12.0, 8.0, -1.2])
b = 45.0

# %%
def predict(x, w, b):
    predict = np.dot(x, w) + b
    return predict

# %%
p = predict([1.75, 3, 2, 20], w, b)
print(f"final price: ${p}")
# Out:
# final price: $388.0

# %%
def compute_cost(x, y, w, b):
    cost = 0
    m = x.shape[0]
    for i in range(m):
        cost += ((np.dot(x[i], w) + b) - y[i]) ** 2
    cost /= 2 * m
    return cost

# %%
cost = compute_cost(x_train, y_train, w, b)
print(f"Cost: {cost}")
# Out:
# Cost: 551.445

# %%
def compute_gradient(x, y, w, b):
    m, n = x.shape
    dj_dw = np.zeros(n)
    dj_db = 0

    for i in range(m):
        error = (np.dot(x[i],w) + b) - y[i]
        for j in range(n):
            dj_dw[j] += error * x[i, j]
        dj_db += error

    dj_dw /= m
    dj_db /= m

    return dj_dw, dj_db

# %%
dj_dw, dj_db = compute_gradient(x_train, y_train, w, b)

print(f"dj_dw: {dj_dw}\ndj_db:{dj_db}")
# Out:
# dj_dw: [ 34.283  67.15   41.05  638.125]
# dj_db:22.349999999999998

# %%
def gradient_descent(x, y, w_init, b_init, alpha, iterations):
    j_history = []

    w = copy.deepcopy(w_init)
    b = b_init
    for i in range(iterations):
        dj_dw, dj_db = compute_gradient(x, y, w, b)
        w = w - (alpha * dj_dw)
        b = b - (alpha * dj_db)


        j_history.append(compute_cost(x, y, w, b))

        if i % math.ceil(iterations / 100) == 0:
            print(f"iteration: {i}, cost: {j_history[-1]:8.2f}")

    return w, b, j_history

# %%
w = np.zeros(x_train.shape[1])
b = 0.
alpha = 5.0e-7
iterations = 100000

final_w, final_b, cost_history = gradient_descent(x_train, y_train, w, b, alpha, iterations)

print(f"Final value of w {final_w}, and b {final_b:.2f}, final cost = {cost_history[-1]:.2f}")
# Out:
# iteration: 0, cost: 60500.75
# iteration: 1000, cost: 34117.80
# iteration: 2000, cost: 25846.25
# iteration: 3000, cost: 23205.97
# iteration: 4000, cost: 22316.81
# iteration: 5000, cost: 21972.39
# iteration: 6000, cost: 21797.65
# iteration: 7000, cost: 21675.98
# iteration: 8000, cost: 21571.12
# iteration: 9000, cost: 21471.79
# iteration: 10000, cost: 21374.49
# iteration: 11000, cost: 21278.13
# iteration: 12000, cost: 21182.36
# iteration: 13000, cost: 21087.08
# iteration: 14000, cost: 20992.25
# iteration: 15000, cost: 20897.87
# iteration: 16000, cost: 20803.92
# iteration: 17000, cost: 20710.40
# iteration: 18000, cost: 20617.31
# iteration: 19000, cost: 20524.65
# iteration: 20000, cost: 20432.42
# iteration: 21000, cost: 20340.61
