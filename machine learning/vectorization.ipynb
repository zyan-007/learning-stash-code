# %%
import numpy as np

# %%
x = np.array([1.0, 2.0, 3.0])
w = np.array([5.0, 6.0, 7.0])
n = len(a)
b = 10

# %%
f = 0
for i in range(n):
    f += x[i] * w[i]
f += b
f
# Out:
# np.float64(48.0)

# %%
f1 = np.dot(x, w) + b
f1
# Out:
# np.float64(48.0)
